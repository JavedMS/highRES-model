# %%
import pathlib
import sqlite3
from multiprocessing import Pool

import pandas as pd

paths = list(
    pathlib.Path("/cluster/work/projects/ec85/joint-wind/model-aggregated/").rglob(
        "results.db"
    )
)

paths2 = []
for path in paths:
    paths2.append(str(path))


def convertdbparq(paths):
    path2 = pathlib.Path(paths)
    p = path2.parent / "results"
    # print(p)
    p.mkdir(parents=True, exist_ok=True)

    conn = sqlite3.connect(path2)
    c = conn.cursor()

    for table in c.execute(
        "SELECT name FROM sqlite_master WHERE type='table';"
    ).fetchall():
        t = table[0]
        # print(t)
        pd.read_sql("SELECT * from " + t, conn).to_parquet(
            p / (t + ".parquet"), compression="zstd"
        )


processes = 10

with Pool(processes) as pool:
    processed = pool.map(convertdbparq, paths2)

# %%
import pathlib
import sqlite3

import pandas as pd

p = pathlib.Path("/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results")
p.mkdir(parents=True, exist_ok=True)


conn = sqlite3.connect("/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results.db")
c = conn.cursor()


for table in c.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall():
    t = table[0]
    print(t)
    #if t == "vre_gen": # and grid
    #    continue
    pd.read_sql("SELECT * from " + t, conn).to_parquet(
        "/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results/" + t + ".parquet", compression="zstd"
    )
# Out:
# lt
# r
# z
# h
# yr
# hr2yr_map
# g
# non_vre
# vre
# trans
# gen_capex
# gen_varom
# gen_fom
# gen_fuelcost
# gen_mingen
# gen_emisfac
# gen_maxramp
# gen_af
# gen_peakaf
# gen_cap2area
# gen_lim_pcap_z
# gen_lim_ecap_z
# gen_exist_pcap_z
# gen_exist_ecap_z
# gen_fx_natcap
# gen_unitsize
# gen_startupcost
# gen_minup
# gen_mindown
# gen_inertia
# trans_links_cap
# trans_links_dist
# trans_loss
# trans_varom
# trans_line_capex
# trans_sub_capex
# area
# vre_gen
# demand
# hydro_res
# gen_uc_int
# gen_uc_lin
# trans_links
# exist_vre_cap_r
# s
# store_pcapex
# store_ecapex
# store_varom
# store_fom
# store_eff_in
# store_eff_out
# store_loss_per_hr
# store_p_to_e
# store_lim_pcap_z
# store_exist_pcap_z
# store_lim_ecap_z
# store_exist_ecap_z
# store_af
# store_max_res
# store_max_freq
# store_minup
# store_mindown
# store_unitsize
# store_mingen
# store_inertia
# store_startupcost
# store_maxramp
# store_uc_lin
# var_store_level
# var_store
# var_store_gen
# var_new_store_pcap_z
# ...

# %%
df = pd.read_parquet("/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results/vre_gen.parquet")

# %%
df = df.set_index(["r","vre","h"])

# %%
df
# Out:
#                               value
# r          vre          h
# x1000y5425 Solar        0       0.0
# x1000y5450 Solar        0       0.0
# x1000y5475 Solar        0       0.0
# x1000y5500 Solar        0       0.0
# x1000y5525 Solar        0       0.0
# ...                             ...
# x975y7200  Windoffshore 8759    1.0
# x975y7225  Windoffshore 8759    1.0
# x975y7250  Windoffshore 8759    1.0
# x975y7275  Windoffshore 8759    1.0
# x975y7300  Windoffshore 8759    1.0
#
# [188340000 rows x 1 columns]

# %%
df.to_parquet("/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results/vre_gen_idx.parquet",compression="zstd")

# %%
df.to_parquet("/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results/vre_gen_idx.parquet",compression="zstd",partition_cols=["h"])
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.to_parquet("/cluster/work/projects/ec85/joint-wind/model-aggregated/resultscosts/models/1995/High_High_High_Low_High_grid_0.0/results/vre_gen_idx.parquet",compression="zstd",partition_cols=["h"])
#
# File ~/miniforge3/envs/analysis_main/lib/python3.11/site-packages/pandas/core/frame.py:2970, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2882 """
#    2883 Write a DataFrame to the binary parquet format.
#    2884
#    (...)
#    2966 >>> content = f.read()
#    2967 """
#    2968 from pandas.io.parquet import to_parquet
# -> 2970 return to_parquet(
#    2971     self,
#    2972     path,
#    2973     engine,
#    2974     compression=compression,
#    2975     index=index,
#    2976     partition_cols=partition_cols,
# ...
